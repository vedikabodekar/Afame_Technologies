# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel(r"D:\Afame tech\Sales Project\ECOMM DATA.xlsx")
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
data.shape
# Out:
# (51290, 24)

# %%
data.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
data = data.drop(['Postal Code'], axis=1)

# %%
data
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Market', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
data['Year'] = data['Order Date'].dt.year
data['Year']
# Out:
# 0        2012
# 1        2013
# 2        2013
# 3        2013
# 4        2013
#          ...
# 51285    2014
# 51286    2014
# 51287    2013
# 51288    2012
# 51289    2012
# Name: Year, Length: 51290, dtype: int64

# %%
data_overtime = data.groupby(['Year', 'Category'])['Sales'].sum().round(2)
data_overtime
# Out:
# Year  Category
# 2011  Furniture           756192.38
#       Office Supplies     675606.45
#       Technology          827652.06
# 2012  Furniture           858902.56
#       Office Supplies     795094.63
#       Technology         1023441.51
# 2013  Furniture          1117723.55
#       Office Supplies    1010717.64
#       Technology         1277305.25
# 2014  Furniture          1378055.69
#       Office Supplies    1305651.51
#       Technology         1616158.67
# Name: Sales, dtype: float64

# %%
data_overtime.unstack().plot(kind='line', figsize=(10, 8))
plt.title('Sales Performance of Different Product Categories Over Time')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.legend(title='Category')
plt.grid(True)
plt.show()

# %% [markdown]
# ************Which customer segments contribute the most to overall sales revenue?************

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Market', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost', 'Order Priority', 'Year'],
#       dtype='object')

# %%
highest_segment = data.groupby(['Segment'])['Sales'].sum().reset_index().round(2)
highest_segment
# Out:
#        Segment       Sales
# 0     Consumer  6507949.42
# 1    Corporate  3824697.52
# 2  Home Office  2309854.97

# %%
plt.bar(highest_segment['Segment'],highest_segment['Sales'], color = "green")
plt.xlabel("Segment")
plt.ylabel("Totla Sales")
plt.title('Customer segments contribute the most to overall sales revenue')
plt.show()

# %% [markdown]
# **What is the average shipping cost per order**

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Market', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost', 'Order Priority', 'Year'],
#       dtype='object')

# %%
average_per_order= data.groupby(['Order ID'])['Shipping Cost'].mean()

# %% [markdown]
# **Are there any noticeable patterns in sales based on geographic regions or market segments?**

# %%
sales_region = data.groupby(['Region'])['Sales'].sum().round()
sales_region
# Out:
# Region
# Africa             783773.0
# Canada              66928.0
# Caribbean          324281.0
# Central           2822303.0
# Central Asia       752827.0
# EMEA               806161.0
# East               678781.0
# North             1248166.0
# North Asia         848310.0
# Oceania           1100185.0
# South             1600907.0
# Southeast Asia     884423.0
# West               725458.0
# Name: Sales, dtype: float64

# %%
sales_region.plot(kind = 'barh', color = 'skyblue')
plt.title('Noticeable patterns in sales based on geographic regions')
plt.xlabel('Sales')
plt.show()

# %%
sales_by_segments = data.groupby(['Segment'])['Sales'].sum().round()
sales_by_segments

sales_by_segments.plot(kind='bar', color= 'pink')
plt.show()

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Market', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost', 'Order Priority', 'Year'],
#       dtype='object')

# %% [markdown]
# **Are there any outliers in terms of sales, profit, or shipping costs?**

# %%
plt.boxplot(data[['Sales','Profit','Shipping Cost']])
plt.show()

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %% [markdown]
# **What is the average discount offered on orders?**

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Market', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost', 'Order Priority', 'Year'],
#       dtype='object')

# %%
data.groupby(['Order ID'])['Discount'].mean().reset_index()
# Out:
#            Order ID  Discount
# 0      AE-2011-9160       0.7
# 1      AE-2013-1130       0.7
# 2      AE-2013-1530       0.7
# 3      AE-2014-2840       0.7
# 4      AE-2014-3830       0.7
# ...             ...       ...
# 25030  ZI-2014-7160       0.7
# 25031  ZI-2014-7610       0.7
# 25032  ZI-2014-9540       0.7
# 25033  ZI-2014-9550       0.7
# 25034  ZI-2014-9650       0.7
#
# [25035 rows x 2 columns]
